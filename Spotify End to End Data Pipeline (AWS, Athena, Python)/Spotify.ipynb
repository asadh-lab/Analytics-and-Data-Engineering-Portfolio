# %%
pip install spotipy
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
import spotipy
from spotipy.oauth2 import SpotifyClientCredentials
import pandas as pd

# %%
client_credentials_manager = SpotifyClientCredentials(client_id="f61e43ad6b3d47059cfcd004b66750cb",client_secret="####3")

# %%
sp = spotipy.Spotify(client_credentials_manager = client_credentials_manager)

# %%
playlist_link ="https://open.spotify.com/playlist/37i9dQZEVXbMDoHDwVN2tF"

# %%
playlist_URI = playlist_link.split("/")[-1]

# %%
data = sp.playlist_tracks(playlist_URI)

# %%
# data

# %%
#{'href': 'https://api.spotify.com/v1/playlists/37i9dQZEVXbMDoHDwVN2tF/tracks?offset=0&limit=100&additional_types=track',
#  'items': [{'added_at': '2024-05-13T09:36:26Z',
#    'added_by': {'external_urls': {'spotify': 'https://open.spotify.com/user/'},
#     'href': 'https://api.spotify.com/v1/users/',
#     'id': '',
#     'type': 'user',
#     'uri': 'spotify:user:'},
#    'is_local': False,
#    'primary_color': None,
#    'track': {'preview_url': 'https://p.scdn.co/mp3-preview/bef167d5462ff8e94b933ffd3f1a17eed0c47f20?cid=f61e43ad6b3d47059cfcd004b66750cb',
#     'available_markets': ['AR',
#      'AU',
#      'AT',
#      'BE',
#      'BO',
#      'BR',
#      'BG',
#      'CA',
#      'CL',
#      'CO',
#      'CR',
#      'CY',
#      'CZ',
#      'DK',
#      'DO',
# ...
#  'limit': 100,
#  'next': None,
#  'offset': 0,
#  'previous': None,
#  'total': 50}

# %%
data["items"][0]
# Out:
# {'added_at': '2024-05-13T09:36:26Z',
#  'added_by': {'external_urls': {'spotify': 'https://open.spotify.com/user/'},
#   'href': 'https://api.spotify.com/v1/users/',
#   'id': '',
#   'type': 'user',
#   'uri': 'spotify:user:'},
#  'is_local': False,
#  'primary_color': None,
#  'track': {'preview_url': 'https://p.scdn.co/mp3-preview/bef167d5462ff8e94b933ffd3f1a17eed0c47f20?cid=f61e43ad6b3d47059cfcd004b66750cb',
#   'available_markets': ['AR',
#    'AU',
#    'AT',
#    'BE',
#    'BO',
#    'BR',
#    'BG',
#    'CA',
#    'CL',
#    'CO',
#    'CR',
#    'CY',
#    'CZ',
#    'DK',
#    'DO',
#    'DE',
#    'EC',
#    'EE',
#    'SV',
#    'FI',
#    'FR',
#    'GR',
#    'GT',
#    'HN',
#    'HK',
#    'HU',
#    'IS',
#    'IE',
#    'IT',
#    'LV',
#    'LT',
#    'LU',
#    'MY',
#    'MT',
#    'MX',
#    'NL',
#    'NZ',
#    'NI',
#    'NO',
#    'PA',
#    'PY',
#    'PE',
#    'PH',
#    'PL',
#    'PT',
#    'SG',
#    'SK',
#    'ES',
#    'SE',
#    'CH',
#    'TW',
# ...

# %%
len(data["items"])
# Out:
# 50

# %%
#Getting albulm id
data['items'][0]['track']['album']['id']
# Out:
# '52TwRwdTUMtkpglbOE5IRz'

# %%
#Getting albulm name
data['items'][0]['track']['album']['name']
# Out:
# 'MILLION DOLLAR BABY'

# %%
#Getting release date
data['items'][0]['track']['album']['release_date']
# Out:
# '2024-04-26'

# %%
#Getting Total Tracks
data['items'][0]['track']['album']['total_tracks']
# Out:
# 2

# %%
#Getting Albulm Type
data['items'][0]['track']['album']['album_type']
# Out:
# 'single'

# %%
#Getting spotify url
data['items'][0]['track']['album']['external_urls']['spotify']
# Out:
# 'https://open.spotify.com/album/52TwRwdTUMtkpglbOE5IRz'

# %%
album_list = []
for row in data['items']:
    album_id = row['track']['album']['id']
    album_name = row['track']['album']['name']
    album_release_date = row['track']['album']['release_date']
    album_total_tracks = row['track']['album']['total_tracks']
    album_type = row['track']['album']['album_type']
    album_spotify_url = row['track']['album']['external_urls']['spotify']
    # print(album_name)
    album_element = {'album_id': album_id, 'name': album_name, 'release_date': album_release_date, 'total_tracks': album_total_tracks, 'album_type': album_type, 'url': album_spotify_url }
    album_list.append(album_element)

# %%
album_list[0]
# Out:
# {'album_id': '52TwRwdTUMtkpglbOE5IRz',
#  'name': 'MILLION DOLLAR BABY',
#  'release_date': '2024-04-26',
#  'total_tracks': 2,
#  'album_type': 'single',
#  'url': 'https://open.spotify.com/album/52TwRwdTUMtkpglbOE5IRz'}

# %%
data['items'][0]
# Out:
# {'added_at': '2024-05-13T09:36:26Z',
#  'added_by': {'external_urls': {'spotify': 'https://open.spotify.com/user/'},
#   'href': 'https://api.spotify.com/v1/users/',
#   'id': '',
#   'type': 'user',
#   'uri': 'spotify:user:'},
#  'is_local': False,
#  'primary_color': None,
#  'track': {'preview_url': 'https://p.scdn.co/mp3-preview/bef167d5462ff8e94b933ffd3f1a17eed0c47f20?cid=f61e43ad6b3d47059cfcd004b66750cb',
#   'available_markets': ['AR',
#    'AU',
#    'AT',
#    'BE',
#    'BO',
#    'BR',
#    'BG',
#    'CA',
#    'CL',
#    'CO',
#    'CR',
#    'CY',
#    'CZ',
#    'DK',
#    'DO',
#    'DE',
#    'EC',
#    'EE',
#    'SV',
#    'FI',
#    'FR',
#    'GR',
#    'GT',
#    'HN',
#    'HK',
#    'HU',
#    'IS',
#    'IE',
#    'IT',
#    'LV',
#    'LT',
#    'LU',
#    'MY',
#    'MT',
#    'MX',
#    'NL',
#    'NZ',
#    'NI',
#    'NO',
#    'PA',
#    'PY',
#    'PE',
#    'PH',
#    'PL',
#    'PT',
#    'SG',
#    'SK',
#    'ES',
#    'SE',
#    'CH',
#    'TW',
# ...

# %%
artist_list = []
for row in data['items']:
    for key, value in row.items():
        if key == 'track':
            for artist in value['artists']:
                artist_dict = {'artist_id': artist['id'], 'artist_name': artist['name'], 'external_url': artist['href']}
                artist_list.append(artist_dict)

# %%
artist_list
# Out:
# [{'artist_id': '1WaFQSHVGZQJTbf0BdxdNo',
#   'artist_name': 'Tommy Richman',
#   'external_url': 'https://api.spotify.com/v1/artists/1WaFQSHVGZQJTbf0BdxdNo'},
#  {'artist_id': '2YZyLoL8N0Wb9xBt1NhZWg',
#   'artist_name': 'Kendrick Lamar',
#   'external_url': 'https://api.spotify.com/v1/artists/2YZyLoL8N0Wb9xBt1NhZWg'},
#  {'artist_id': '74KM79TiuVKeVCqs8QtB0B',
#   'artist_name': 'Sabrina Carpenter',
#   'external_url': 'https://api.spotify.com/v1/artists/74KM79TiuVKeVCqs8QtB0B'},
#  {'artist_id': '246dkjvS1zLTtiykXe5h60',
#   'artist_name': 'Post Malone',
#   'external_url': 'https://api.spotify.com/v1/artists/246dkjvS1zLTtiykXe5h60'},
#  {'artist_id': '4oUHIQIBe0LHzYfvXNW4QM',
#   'artist_name': 'Morgan Wallen',
#   'external_url': 'https://api.spotify.com/v1/artists/4oUHIQIBe0LHzYfvXNW4QM'},
#  {'artist_id': '0PCCGZ0wGLizHt2KZ7hhA2',
#   'artist_name': 'Artemas',
#   'external_url': 'https://api.spotify.com/v1/artists/0PCCGZ0wGLizHt2KZ7hhA2'},
# ...

# %%
song_list = []
for row in data['items']:
    song_id = row['track']['id']
    song_name = row['track']['name']
    song_duration = row['track']['duration_ms']
    song_url = row['track']['external_urls']['spotify']
    song_popularity = row['track']['popularity']
    song_added = row['added_at']
    album_id = row['track']['album']['id']
    artist_id = row['track']['album']['artists'][0]['id']
    song_element = {'song_id':song_id,'song_name':song_name,'duration_ms':song_duration,'url':song_url,
                    'popularity':song_popularity,'song_added':song_added,'album_id':album_id,
                    'artist_id':artist_id
                   }
    song_list.append(song_element)

# %%
song_list[0]
# Out:
# {'song_id': '7fzHQizxTqy8wTXwlrgPQQ',
#  'song_name': 'MILLION DOLLAR BABY',
#  'duration_ms': 155151,
#  'url': 'https://open.spotify.com/track/7fzHQizxTqy8wTXwlrgPQQ',
#  'popularity': 94,
#  'song_added': '2024-05-13T09:36:26Z',
#  'album_id': '52TwRwdTUMtkpglbOE5IRz',
#  'artist_id': '1WaFQSHVGZQJTbf0BdxdNo'}

# %%
album_df = pd.DataFrame.from_dict(album_list)

# %%
album_df.head()
# Out:
#                  album_id                        name release_date  \
# 0  52TwRwdTUMtkpglbOE5IRz         MILLION DOLLAR BABY   2024-04-26
# 1  5JjnoGJyOxfSZUZtk2rRwZ                 Not Like Us   2024-05-04
# 2  5quMTd5zeI9yW5UDua8wS4                    Espresso   2024-04-12
# 3  1woYXxyyxTQJ0E0AhZE6mj             I Had Some Help   2024-05-10
# 4  5HIWDdg3g9CTOtnevKDl1z  i like the way you kiss me   2024-03-19
#
#    total_tracks album_type                                                url
# 0             2     single  https://open.spotify.com/album/52TwRwdTUMtkpgl...
# 1             1     single  https://open.spotify.com/album/5JjnoGJyOxfSZUZ...
# 2             1     single  https://open.spotify.com/album/5quMTd5zeI9yW5U...
# 3             1     single  https://open.spotify.com/album/1woYXxyyxTQJ0E0...
# 4             1     single  https://open.spotify.com/album/5HIWDdg3g9CTOtn...

# %%
album_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 50 entries, 0 to 49
# Data columns (total 6 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   album_id      50 non-null     object
#  1   name          50 non-null     object
#  2   release_date  50 non-null     object
#  3   total_tracks  50 non-null     int64
#  4   album_type    50 non-null     object
#  5   url           50 non-null     object
# dtypes: int64(1), object(5)
# memory usage: 2.5+ KB

# %%
artist_df = pd.DataFrame.from_dict(artist_list)

# %%
artist_df.head()
# Out:
#                 artist_id        artist_name  \
# 0  1WaFQSHVGZQJTbf0BdxdNo      Tommy Richman
# 1  2YZyLoL8N0Wb9xBt1NhZWg     Kendrick Lamar
# 2  74KM79TiuVKeVCqs8QtB0B  Sabrina Carpenter
# 3  246dkjvS1zLTtiykXe5h60        Post Malone
# 4  4oUHIQIBe0LHzYfvXNW4QM      Morgan Wallen
#
#                                         external_url
# 0  https://api.spotify.com/v1/artists/1WaFQSHVGZQ...
# 1  https://api.spotify.com/v1/artists/2YZyLoL8N0W...
# 2  https://api.spotify.com/v1/artists/74KM79TiuVK...
# 3  https://api.spotify.com/v1/artists/246dkjvS1zL...
# 4  https://api.spotify.com/v1/artists/4oUHIQIBe0L...

# %%
artist_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 65 entries, 0 to 64
# Data columns (total 3 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   artist_id     65 non-null     object
#  1   artist_name   65 non-null     object
#  2   external_url  65 non-null     object
# dtypes: object(3)
# memory usage: 1.7+ KB

# %%
artist_df.drop_duplicates(subset=['artist_id'])
# Out:
#                  artist_id        artist_name  \
# 0   1WaFQSHVGZQJTbf0BdxdNo      Tommy Richman
# 1   2YZyLoL8N0Wb9xBt1NhZWg     Kendrick Lamar
# 2   74KM79TiuVKeVCqs8QtB0B  Sabrina Carpenter
# 3   246dkjvS1zLTtiykXe5h60        Post Malone
# 4   4oUHIQIBe0LHzYfvXNW4QM      Morgan Wallen
# 5   0PCCGZ0wGLizHt2KZ7hhA2            Artemas
# 6   06HL4z0CvFAxyc27GXpf02       Taylor Swift
# 8   7CvTknweLr9feJtRGrpDBy         FloyyMenor
# 9   1Yj5Xey7kTwvZla8sqdsdE            Cris Mj
# 10  3y2cIKLjiOlp1Np37WiUdH          Shaboozey
# 11  22wbnEMDvgVIAGdFeek6ET       Benson Boone
# 12  2FXC3k01G6Gw61bmprjgqS             Hozier
# 13  66CXWjxzNUsdJxJ2JdwvnR      Ariana Grande
# 14  5p9HO3XC5P3BLxJs5Mtrhm                Djo
# 17  1RyvyyTE3xzB2ZywiAwp0i             Future
# 18  0iEtIxbK0KxaSlF7G42ZOp       Metro Boomin
# 20  33qOK5uJ8AR2xuQQAhHump        Teddy Swims
# 21  5Wg72TowYBWIcSo3K2r84N               Nemo
# 22  7tYKF4w9nC0nq9CsPZTHyP                SZA
# ...

# %%
song_df = pd.DataFrame.from_dict(song_list)

# %%
song_df.head()
# Out:
#                   song_id                              song_name  duration_ms  \
# 0  7fzHQizxTqy8wTXwlrgPQQ                    MILLION DOLLAR BABY       155151
# 1  6AI3ezQ4o3HUoP6Dhudph3                            Not Like Us       274192
# 2  2qSkIjg1o9h3YT9RAgYN75                               Espresso       175459
# 3  7221xIgOnuakPdLqT0F3nP  I Had Some Help (Feat. Morgan Wallen)       178205
# 4  2GxrNKugF82CnoRFbQfzPf             i like the way you kiss me       142514
#
#                                                  url  popularity  \
# 0  https://open.spotify.com/track/7fzHQizxTqy8wTX...          94
# 1  https://open.spotify.com/track/6AI3ezQ4o3HUoP6...          94
# 2  https://open.spotify.com/track/2qSkIjg1o9h3YT9...          99
# 3  https://open.spotify.com/track/7221xIgOnuakPdL...          86
# 4  https://open.spotify.com/track/2GxrNKugF82CnoR...         100
#
#              song_added                album_id               artist_id
# ...

# %%
song_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 50 entries, 0 to 49
# Data columns (total 8 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   song_id      50 non-null     object
#  1   song_name    50 non-null     object
#  2   duration_ms  50 non-null     int64
#  3   url          50 non-null     object
#  4   popularity   50 non-null     int64
#  5   song_added   50 non-null     object
#  6   album_id     50 non-null     object
#  7   artist_id    50 non-null     object
# dtypes: int64(2), object(6)
# memory usage: 3.3+ KB

# %%
album_df['release_date'] = pd.to_datetime(album_df['release_date'])
album_df.head(5)
# Out:
#                  album_id                        name release_date  \
# 0  52TwRwdTUMtkpglbOE5IRz         MILLION DOLLAR BABY   2024-04-26
# 1  5JjnoGJyOxfSZUZtk2rRwZ                 Not Like Us   2024-05-04
# 2  5quMTd5zeI9yW5UDua8wS4                    Espresso   2024-04-12
# 3  1woYXxyyxTQJ0E0AhZE6mj             I Had Some Help   2024-05-10
# 4  5HIWDdg3g9CTOtnevKDl1z  i like the way you kiss me   2024-03-19
#
#    total_tracks album_type                                                url
# 0             2     single  https://open.spotify.com/album/52TwRwdTUMtkpgl...
# 1             1     single  https://open.spotify.com/album/5JjnoGJyOxfSZUZ...
# 2             1     single  https://open.spotify.com/album/5quMTd5zeI9yW5U...
# 3             1     single  https://open.spotify.com/album/1woYXxyyxTQJ0E0...
# 4             1     single  https://open.spotify.com/album/5HIWDdg3g9CTOtn...

# %%
song_df['song_added'] = pd.to_datetime(song_df['song_added'])
song_df.head(5)
# Out:
#                   song_id                              song_name  duration_ms  \
# 0  7fzHQizxTqy8wTXwlrgPQQ                    MILLION DOLLAR BABY       155151
# 1  6AI3ezQ4o3HUoP6Dhudph3                            Not Like Us       274192
# 2  2qSkIjg1o9h3YT9RAgYN75                               Espresso       175459
# 3  7221xIgOnuakPdLqT0F3nP  I Had Some Help (Feat. Morgan Wallen)       178205
# 4  2GxrNKugF82CnoRFbQfzPf             i like the way you kiss me       142514
#
#                                                  url  popularity  \
# 0  https://open.spotify.com/track/7fzHQizxTqy8wTX...          94
# 1  https://open.spotify.com/track/6AI3ezQ4o3HUoP6...          94
# 2  https://open.spotify.com/track/2qSkIjg1o9h3YT9...          99
# 3  https://open.spotify.com/track/7221xIgOnuakPdL...          86
# 4  https://open.spotify.com/track/2GxrNKugF82CnoR...         100
#
#                  song_added                album_id               artist_id
# ...
